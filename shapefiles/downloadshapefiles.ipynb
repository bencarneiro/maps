# %%
import pandas as pd
import requests, zipfile, io
import os
headers = {
    'Referer': 'https://www.census.gov/',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Not(A:Brand";v="8", "Chromium";v="144", "Google Chrome";v="144"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
}

# %%
test = pd.read_html("https://www2.census.gov/geo/tiger/TIGER2024/TRACT/")

# %%
if not os.path.exists(newpath):
    os.makedirs(newpath)

# %%
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("/path/to/destination_directory")

# %%
for x in test[0][2:-1].index:
    slug = test[0]['Name'][int(x)]
    state_fips = slug.split("2024_")[1].split("_")[0]
    new_path = f"/home/tonydeals/app/maps/shapefiles/2024/{state_fips}"
    if not os.path.exists(new_path):
        os.makedirs(new_path)
    r = requests.get(f'https://www2.census.gov/geo/tiger/TIGER2024/TRACT/{slug}', headers=headers)
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall(new_path)
    # break
